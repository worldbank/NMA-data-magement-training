# %% [markdown]
# # Data Handling and Visualization  in Python
# -----
# In this tutorial, you will learn about the basics of working with regular and geospatial data in Python. We will cover the following topics:
# - Loading and handling data using the ```pandas``` package in Python
# - Creating interactive visualizations with Bokeh
# - Automating geospatial data processing tasks using ```geopandas``` in Python
# - Working with documents/natural language data in Python

# %% [markdown]
# # Learning Outomes
# After going through this notebook, the leaner should:
# - Be familiar with  Pandas as a key data wrangling package in Python
# - Create and manipulate pandas dataframes
# - Create a simple visualization with Bokeh
# - Create GeoDataFrames from shapefiles using Geopandas
# - Create simple geo-proceessing with geopandas
# - Appreciate the Python package ecoystem for data science and geospatial data

# %% [markdown]
# # Required Packages
# For this tutorial, we need the following Python packages to be installed:
# - [Pandas](https://pandas.pydata.org). This is a defacto data processing package in Python. It is often pre-installed with Anaconda.
# - [Numpy](https://numpy.org). A package for working with arrays and perfoming linear algebra operations
# - [Geopandas](https://geopandas.org/en/stable/getting_started/install.html). This is similar to Pandas but its for working with geospatial data. This needs to be installed.
# - [Bokeh](https://bokeh.org). A package for creative lively and interactive visualizations

# %% [markdown]
# # Introducing the Packages

# %% [markdown]
# ## Basic Data Handling with Pandas
# Pandas is a library written for the Python programming language for data manipulation and analysis. In particular, it offers data structures and operations for manipulating numerical tables and time series. Pandas is free software released under the three-clause BSD license.

# %%
import pandas as pd

# %% [markdown]
# ### Main Data Structures in Pandas
# Pandas has two mainndata structures as follows: Series, DataFrames and Panels.
# 1. **Series:** A 1-dimensional labelled array that can hold data of any type (integer, string, float, python objects, etc.).
#     It’s axis labels are collectively called an index.
# 2. **DataFrame:** A 2-dimensional labelled data structure with columns and both a row and a column index. A dataframe can
#     be used to represent 3-D data using multiindexing.
#
# A dataframe is often abbreviated as ```df```.

# %% [markdown]
# ### Pandas Series

# %%
data = ['Dunstan','Mercy','Khama','Lara','Khali','Gloria']
names = pd.Series(data)
print (names)
# Out:
# 0    Dunstan
# 1      Mercy
# 2      Khama
# 3       Lara
# 4      Khali
# 5     Gloria
# dtype: object

# %%
data = {"name":['Dunstan','Mercy','Khama','Lara','Khali','Gloria']}
names = pd.Series(data)

# %% [markdown]
# ### Pandas Dataframe

# %%
data = {"name":['Dunstan','Mercy','Khama','Lara','Khali','Gloria'],
       "age": [100, 20, 7, 11, 30, 88]}
df = pd.DataFrame(data)

# %%
df.head(5)
# Out:
#       name  age
# 0  Dunstan  100
# 1    Mercy   20
# 2    Khama    7
# 3     Lara   11
# 4    Khali   30

# %% [markdown]
# ### Data Ingestion with Pandas: A Case of CSV file
# Pandas can work with many data stores and file formats. To take a quick look at what file formats pandas can read, type ```pd.read``` and then hit tab, you should see a list of all the file formats supported by pandas. In this example, we show reading from a CSV file.

# %%
# import the pandas package 
import pandas as pd
from pathlib import Path

# Set the name of the CSV file
fpath = '../data/revenues-received-by-government-agencies-sierra-leone.csv'
data_file = Path(fpath)

# Read data into dataframe
# dataframe is the pandas object for handling tabular data
df = pd.read_csv(data_file)
df.head()
# Out:
#                     created                   changed       country iso3  \
# 0  2017-02-15T00:00:00+0000  2017-02-15T00:00:00+0000  Sierra Leone  SLE
# 1  2017-02-15T00:00:00+0000  2017-02-15T00:00:00+0000  Sierra Leone  SLE
# 2  2017-02-15T00:00:00+0000  2017-02-15T00:00:00+0000  Sierra Leone  SLE
# 3  2017-02-15T00:00:00+0000  2017-02-15T00:00:00+0000  Sierra Leone  SLE
# 4  2017-02-15T00:00:00+0000  2017-02-15T00:00:00+0000  Sierra Leone  SLE
#
#    year  start_date    end_date            government_agency_name  gfs_code  \
# 0  2006  2006-01-01  2006-12-31  National Revenue Authority (NRA)   1112-E1
# 1  2006  2006-01-01  2006-12-31  National Revenue Authority (NRA)   1112-E1
# 2  2006  2006-01-01  2006-12-31  National Revenue Authority (NRA)  114521-E
# 3  2006  2006-01-01  2006-12-31  National Revenue Authority (NRA)  114521-E
# 4  2006  2006-01-01  2006-12-31  National Revenue Authority (NRA)  114521-E
#
#                                      gfs_description  \
# ...

# %%
my_data = [{'name':'Dunstan', 'age':50}, {'name':'Khama', 'age':1}]
df_from_list = pd.DataFrame(my_data)
df_from_list
# Out:
#       name  age
# 0  Dunstan   50
# 1    Khama    1

# %% [markdown]
# ### Exploring Data
# Once you have read the data, pandas has many functions to allow you explore the data

# %%
# View the n-top rows of the data
df.head()
# Out:
#                     created                   changed       country iso3  \
# 0  2017-02-15T00:00:00+0000  2017-02-15T00:00:00+0000  Sierra Leone  SLE
# 1  2017-02-15T00:00:00+0000  2017-02-15T00:00:00+0000  Sierra Leone  SLE
# 2  2017-02-15T00:00:00+0000  2017-02-15T00:00:00+0000  Sierra Leone  SLE
# 3  2017-02-15T00:00:00+0000  2017-02-15T00:00:00+0000  Sierra Leone  SLE
# 4  2017-02-15T00:00:00+0000  2017-02-15T00:00:00+0000  Sierra Leone  SLE
#
#    year  start_date    end_date            government_agency_name  gfs_code  \
# 0  2006  2006-01-01  2006-12-31  National Revenue Authority (NRA)   1112-E1
# 1  2006  2006-01-01  2006-12-31  National Revenue Authority (NRA)   1112-E1
# 2  2006  2006-01-01  2006-12-31  National Revenue Authority (NRA)  114521-E
# 3  2006  2006-01-01  2006-12-31  National Revenue Authority (NRA)  114521-E
# 4  2006  2006-01-01  2006-12-31  National Revenue Authority (NRA)  114521-E
#
#                                      gfs_description  \
# ...

# %%
# Check datatypes and other info about the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   created                 176 non-null    object
#  1   changed                 176 non-null    object
#  2   country                 176 non-null    object
#  3   iso3                    176 non-null    object
#  4   year                    176 non-null    int64
#  5   start_date              176 non-null    object
#  6   end_date                176 non-null    object
#  7   government_agency_name  175 non-null    object
#  8   gfs_code                176 non-null    object
#  9   gfs_description         176 non-null    object
#  10  name_of_revenue_stream  176 non-null    object
#  11  currency_code           176 non-null    object
#  12  currency_rate           0 non-null      float64
#  13  value_reported          0 non-null      float64
# ...

# %%
# Get summary statistics if it makes sense
df.describe()
# Out:
#               year  currency_rate  value_reported  value_reported_as_USD
# count   176.000000            0.0             0.0           1.760000e+02
# mean   2011.926136            NaN             NaN           1.729395e+06
# std       3.038834            NaN             NaN           4.980469e+06
# min    2006.000000            NaN             NaN           0.000000e+00
# 25%    2010.000000            NaN             NaN           3.327238e+04
# 50%    2013.000000            NaN             NaN           2.989522e+05
# 75%    2014.000000            NaN             NaN           1.229229e+06
# max    2016.000000            NaN             NaN           3.765419e+07

# %%
df.head()

# %%
array = df.values
print(type(array))

# %% [markdown]
# ### Next Steps with Pandas
# Please refer to pandas [documentation](http://pandas.pydata.org/pandas-docs/stable/10min.html) for tutorials on how to perfom various tasks such as indexing rows, subsetting the data, chaning column names and more.

# %% [markdown]
# ## Working with arrays using Numpy
# **Numpy** is one of the underlying libraries which powers many high level packages such as pandas. In most case, you will not need to interact with **Numpy** directly but its an essential package for data manipulation and scientific computing in Python. Its useful for linear algebra, Fourier transform, and random number capabilities because it has advanced array/matrix functionalities. Also, most of the machine learning packages do require input as **Numpy** arrays.

# %%
# import Numpy
import numpy as np

# create two arrays
x = np.array([i + 100 for i in range(10)])
y = np.array([i -10 for i in range(10)])

# create a dictionary with key as column name and value as the numpy arrays
data = {"x": x, "y":y}

# Use the dictinary to create a pandas dataframe
df_from_np = pd.DataFrame(data)

# Check out the dataframe
df_from_np.head()

# %%
np_array = np.array([1,2,3])
np_array

# %%
x = np.array([i + 100 for i in range(10)])
x

# %% [markdown]
# ## Working with  Geospatial Data in Python
# As a mining agency, you often have to deal with geeospatial data. Python has a suite of tools for handling spatial data as we will show in the next section.
# - [GDAL](https://www.gdal.org): this is one of the core libraries for provising geospatial data functionality. Most of the other libraries are based on GDAL.
# - [Geopandas](http://geopandas.org): A pandas version for geospatial data
# - [Shapely](https://shapely.readthedocs.io/en/stable/manual.html): yet another spatial data library with alot of functionalities.
# - [Rasterio](https://rasterio.readthedocs.io/en/latest/quickstart.html). This is the main library for working with raster datasets.
# - [rasterstats](https://pythonhosted.org/rasterstats/). An additional package for working with raster data

# %% [markdown]
# ## Reading Shapefiles with GDAL OGR Library
# GDAL s a translator library for raster and vector geospatial data formats that is released under an X/MIT style Open Source license by the Open Source Geospatial Foundation. Its also used in oen source GIS software such as QGIS. In Python, you can use the library to read raster and vector data as well as manipulate them.

# %%
# import package
from osgeo import ogr

# shapefile path
shp_file = '../data/Section.shp'

# open shapefile
file = ogr.Open(shp_file)
shape = file.GetLayer(0)

#first feature of the shapefile
feature = shape.GetFeature(0)

# Convert first feature to GeoJSON
first = feature.ExportToJson()

# print the JSON object
first

# %%
import geopandas as gpd
from matplotlib import pyplot as plt

# %%
shp_file = '../data/Section.shp'
gdf = gpd.read_file(shp_file)
gdf.plot()
plt.show()

# %% [markdown]
# ### Displaying Spatial Data with Geopandas
# GeoPandas is an open source project to make working with geospatial data in python easier. GeoPandas extends the datatypes used by pandas to allow spatial operations on geometric types.

# %%
# import geopandas
import geopandas as gpd

# read the shapefile which we arleady defined in cells above
df = gpd.read_file(shp_file)

# diplay the shapefile 
display(df.plot(figsize=(8, 8)))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Example Data Science Tasks

# %% [markdown]
# ## A Simple geoprocessing task
# Given two datasets as follows: a polygon dataset with section boundaries and corresponding population and a point datasete of building footprints,
# generate building counts for each section. As previously mentioned, the advantage of doing this in Python as opposed to Desktop GIS is the ability to automate  and run this process again without extra effort.

# %%
buildings_file = "../data/google-building-footprints-sample.shp"
section_pop_file = "../data/Section.shp"

# %%
# Read the shapefiles using Geopandas
#gdf_bld = gpd.read_file(buildings_file)
gdf_sect = gpd.read_file(section_pop_file)

# %%
# We gonna use SCODE as a unique ID for each section and verify that its indeed unique for each row below
assert gdf_sect.SCODE.nunique() == gdf_sect.shape[0]

# %%
# perfom spatial join for the polygon and  point shapefiles
gdf_sect_bld = gpd.sjoin(left_df=gdf_sect, right_df=gdf_bld, how='inner', predicate='contains')

# %%
# count points in polygons by using groupby
gdf_sect_bld_grp = gdf_sect_bld.groupby(['SCODE']).size().reset_index()

# %%
# add better namee for building count and re-merge with the Section shapefile
gdf_sect_bld_grp.rename(columns={0: 'bld_cnt'}, inplace=True)
gdf_sect_bld = gdf_sect.merge(gdf_sect_bld_grp, on='SCODE', how='inner')

# %%
# Ensure everything matched perfectly 
assert gdf_sect.shape[0] == gdf_sect_bld.shape[0]

# %% [markdown]
# ### And lets do some sanity check

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
corr = pd.DataFrame.corr(gdf_sect_bld[['SUM_TOTPOP','bld_cnt']])

# %%
corr_text = corr.iloc[0]['bld_cnt']
corr_text
# Out:
# 0.8470172140524294

# %%
plt.figure(figsize=(10,8))
#sns.scatterplot(data=gdf_sect_bld, x='SUM_TOTPOP', y='bld_cnt')
sns.regplot(data=gdf_sect_bld, x='SUM_TOTPOP', y='bld_cnt', line_kws={'color': 'g'})
plt.text(42000, 5000, "R-squared = {}".format(round(corr_text, 2)), horizontalalignment='left', size='large', color='green', weight='semibold')
plt.xlabel('2015 population')
plt.ylabel('Google building counts')
plt.title("Exploring correlation between buildings and population")
# Out:
# Text(0.5, 1.0, 'Exploring correlation between buildings and population')

# %% [markdown]
# # Interactive Data Visualization
# Python has many data visualisation tools, here are some of them:
# - [Matplotlib]() : this is the base plotting engine in Python. Most of the other packages are somehow based on it.
# - [Seaborn](): A relatively new packahe with more colourful plots
# - [Bokeh](): this is an interactive visualization library that targets modern web browsers for presentation.

# %% [markdown]
# ## Interactive Visualisations with Bokeh
#
# The simple interactive example below has been copied from [Bokeh Documentation] (https://demo.bokehplots.com/apps/moviesfrom) for demonstration.

# %%
from bokeh.plotting import figure, show, output_file
import numpy as np
N = 4000
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = [
    "#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)
]

TOOLS="hover,crosshair,pan,wheel_zoom,zoom_in,zoom_out,box_zoom,undo,redo,reset,tap,save,box_select,poly_select,lasso_select,"

p = figure(tools=TOOLS)

p.scatter(x, y, radius=radii,
          fill_color=colors, fill_alpha=0.6,
          line_color=None)

output_file("color_scatter.html", title="color_scatter.py example")

# please inspect the plot in the browser
show(p)

# %% [markdown]
# # Documents as Data
# This is simply the idea that we can analyze anything these days including unstructured data in the form of documents. For example, if you have historical documents on mining, we can use tools in Python to explore whats in those documents.

# %%
# Install PyPDF2 if its not available
try:
    from PyPDF2 import PdfReader
    import PyPDF2
    from wordcloud import WordCloud, STOPWORDS
    import re
    import matplotlib.pyplot as plt
except:
    # !pip install PyPDF2
    # !pip install wordcloud

# %% [markdown]
# ### Explore most prevalent words in a document using wordcloud

# %%
def convert_pdf_pages_into_text(the_document):
    """
    Loads a PDF document and converts each page content into text string
    """
    # Get text from all pages and put in a list
    reader = PdfReader(the_document)
    number_of_pages = len(reader.pages)
    page_texts = []
    for i in range(number_of_pages):
        try:
            page = reader.pages[i]
            text = page.extract_text()
            text = re.sub(r'==.*?==+', '', text)
            text = text.replace('\n', '')
            page_texts.append(text)
        except:
            pass
    
    # Combine all pages text into one text string
    text = ",".join(page_texts)
    
    return text

# %%
# Define a function to plot word cloud
def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(40, 30))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off")

# %% [markdown]
# #### Create a wordcloud

# %%
# Load text from the document
transparency_document = "../data/documents-as-data/Mainstreaming Transparency.pdf"
text = convert_pdf_pages_into_text(transparency_document)


# Create a WordCloud object
wordcloud = WordCloud(width= 2000, height = 1000, random_state=1, background_color='salmon', colormap='Pastel1', 
                      collocations=False, stopwords = STOPWORDS, max_words=100)

# Generate a word cloud
wordcloud.generate(text)

# Plot the wordcloud
plot_cloud(wordcloud)

# %% [markdown]
# #### EXERCISE-Copy contents of the previous cell above and create a worcloud for the following documents.
# 1. ```SLEITI 2019 Report.pdf``` report
# 2. ```MobileDataAndCovid19.pdf``` paper

# %%
# ADD YOUR CODE HERE FOR FIRST DOCUMENT

# %%
# ADD YOUR CODE HERE FOR SECOND DOCUMENT
# Load text from the document
transparency_document = "../data/documents-as-data/MobileDataAndCovid19.pdf"
text = convert_pdf_pages_into_text(transparency_document)

# Create a WordCloud object
wordcloud = WordCloud(width= 2000, height = 1000, random_state=1, background_color='salmon', colormap='Pastel1', 
                      collocations=False, stopwords = STOPWORDS, max_words=100)

# Generate a word cloud
wordcloud.generate(text)

# Plot the wordcloud
plot_cloud(wordcloud)

# %% [markdown]
# ### Explore topics in a document a.k.a topic modelling
# Given a collection of documents or a single document, explore the prevalent topics within that document or the collection of documents.

# %%
# Install PyPDF2 if its not available
try:
    import pickle 
    import gensim
    import pyLDAvis.gensim_models
    import pyLDAvis
    import gensim.corpora as corpora
    from gensim.utils import simple_preprocess
    import nltk
    from nltk.tokenize import TweetTokenizer, sent_tokenize, RegexpTokenizer
    nltk.download('stopwords')
    from nltk.corpus import stopwords
    from pprint import pprint
except:
    # !pip install gensim
    # !pip install nltk
    # !pip install pyLDAvis
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/dmatekenya/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### preprocess the data/text

# %%
def remove_stopwords(texts):
    words = []
    for word in texts:
        if word in stopwords:
            continue
        else:
            words.append(word)
    return words

# %%
transparency_document = "../data/documents-as-data/Mainstreaming Transparency.pdf"
text = convert_pdf_pages_into_text(transparency_document)
text

# %%
tokenizer = RegexpTokenizer(r'\w+')
stop = list(set(stopwords.words('english')))
data_words = [i.lower() for i in tokenizer.tokenize(text) if i not in stop]
data_words

# %%
# Create Dictionary
id2word = corpora.Dictionary([data_words])
# Create Corpus
texts = data_words
# Term Document Frequency
corpus = [id2word.doc2bow([text]) for text in texts]
# View
print(corpus[:1][0][:30])
# Out:
# [(748, 1)]

# %%
# number of topics
num_topics = 10
# Build LDA model
lda_model = gensim.models.LdaMulticore(corpus=corpus,
                                       id2word=id2word,
                                       num_topics=num_topics)
# Print the Keyword in the 10 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.029*"revenue" + 0.025*"system" + 0.025*"online" + 0.025*"sierra" + '
#   '0.021*"mcas" + 0.017*"transparency" + 0.017*"also" + 0.017*"available" + '
#   '0.017*"artisanal" + 0.013*"government"'),
#  (1,
#   '0.116*"mining" + 0.060*"data" + 0.024*"directly" + 0.024*"government" + '
#   '0.020*"phase" + 0.020*"challenges" + 0.016*"key" + 0.012*"national" + '
#   '0.012*"e" + 0.012*"result"'),
#  (2,
#   '0.045*"data" + 0.029*"mining" + 0.029*"administration" + 0.025*"task" + '
#   '0.025*"cadastre" + 0.021*"repository" + 0.016*"reporting" + 0.016*"report" '
#   '+ 0.016*"production" + 0.012*"eiti"'),
#  (3,
#   '0.041*"eiti" + 0.023*"regional" + 0.014*"revenue" + 0.014*"made" + '
#   '0.014*"tax" + 0.014*"later" + 0.014*"procedures" + 0.014*"electronic" + '
#   '0.010*"mcas" + 0.010*"resources"'),
#  (4,
#   '0.023*"process" + 0.017*"licenses" + 0.017*"payments" + 0.013*"mcas" + '
#   '0.013*"publication" + 0.013*"2" + 0.013*"revenues" + 0.013*"stakeholders" + '
# ...

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
LDAvis_data_filepath = 'ldavis_prepared_{}'.format(num_topics)
# # this is a bit time consuming - make the if statement True
# # if you want to execute visualization prep yourself
if 1 == 1:
    LDAvis_prepared = pyLDAvis.gensim_models.prepare(lda_model, corpus, id2word)
    with open(LDAvis_data_filepath, 'wb') as f:
        pickle.dump(LDAvis_prepared, f)
# load the pre-prepared pyLDAvis data from disk
with open(LDAvis_data_filepath, 'rb') as f:
    LDAvis_prepared = pickle.load(f)
pyLDAvis.save_html(LDAvis_prepared, 'ldavis_prepared_{}.html'.format(num_topics))
LDAvis_prepared
# Out:
# /Users/dmatekenya/opt/anaconda3/lib/python3.9/site-packages/pyLDAvis/_prepare.py:246: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   default_term_info = default_term_info.sort_values(
# /Users/dmatekenya/opt/anaconda3/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/dmatekenya/opt/anaconda3/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Users/dmatekenya/opt/anaconda3/lib/python3.9/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# ...

# %% [markdown]
# #### EXERCISE: Try topic modelling with another document of your choice

# %% [markdown]
# ### Document classification
# Finally, if given labels describing a topic for each document, we can use words/terms in a document to train a model which can

# %% [markdown]
# # What else can you do with Python?

# %% [markdown]
# ## 1. Work with images better by utilizing state of the art computer vision techniques
# Again, as NMA you may work with alot of pictures from mining activities. In Python, its easier to train machine learning models to extract information from images. For a quick appreciation of whats possible with computeer vision, check out [Google vision APIs](https://cloud.google.com/vision) where you cann upload an image and extract its contents.
# ## 2. Automating data processing pipelines
# As mentioned before, its easier to create automated data pipelines using Python scripts than doing it in desktop applications. Python works beatifully with OS automation systems such as ```chronjob``` for Linux based systems and others so that you can schedule your scripts to run routinely.

# %% [markdown]
# # Further resources for learning Python

# %% [markdown]
# The sites below have free courses which can get you an introductory to intermediate course in Python.
# 1. [Datacamp](https://www.datacamp.com/?irclickid=1lL12fx6UxyNTzy2N4UOMVoGUkDUnvwx1SVARo0&irgwc=1&utm_medium=affiliate&utm_source=impact&utm_campaign=000000_1-2530871_2-mix_3-all_4-na_5-na_6-na_7-mp_8-affl-ip_9-na_10-bau_11-Shisham%20Digital%20Media%20Pvt%20Ltd&utm_content=ONLINE_TRACKING_LINK)
# 2. [Udacity](https://www.udacity.com)
# 3. [Udemy](https://www.udemy.com)
# 4. [Coursera](https://www.udemy.com)
